# %%
import maxim_varios
from importlib import reload
reload(maxim_varios)
# Out:
# <module 'maxim_varios' from 'c:\\Users\\Manu\\OneDrive\\Escritorio\\UTN\\Simulación\\TP6\\maxim_varios.py'>

# %%
maxm = maxim_varios.Maximizacion(2, n_loops=10_000, n_repeticiones=5, alphas=[0.01, 0.0001], hs =[1, 0.1], multiprocesamiento=True)
maxm.generar_punto_de_partida()
maxm.optimizar()
# Out:
# Iteración 0 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 1 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 2 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 3 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 4 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 5 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 6 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 7 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 8 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 9 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 10 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 11 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 12 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 13 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 14 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 15 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 16 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 17 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 18 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 19 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 20 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 21 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 22 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 23 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 24 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 25 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 26 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 27 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 28 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 29 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 30 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 31 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 32 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 33 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 34 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 35 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 36 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 37 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 38 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 39 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 40 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 41 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 42 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 43 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 44 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 45 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 46 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 47 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 48 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 49 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 50 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 51 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 52 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 53 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 54 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 55 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 56 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 57 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 58 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 59 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 60 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 61 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 62 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 63 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 64 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 65 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 66 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 67 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 68 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 69 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# Iteración 70 Punto: [0.45590933956813917, 0.11212279172258688] Resultado: 747.4557310844426
#  Gradientes: [0.0, 0.0]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import plotly.graph_objs as go
from math import floor

# Example list of tuples (x, y, z)
#data = [max.tracking[floor(len(max.tracking)/10)*i-1] for i in range(10)]
data = maxm.tracking

# Extracting x, y, z coordinates from the list of tuples

# Extracting x, y, z coordinates from the list of tuples
x = [point[0] for point in data]
y = [point[1] for point in data]
z = [point[2] for point in data]

# Create trace for the curve
trace_curve = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='lines',
    line=dict(color='blue', width=3),
    name='Curve'
)

# Create traces for the directional arrows
arrows = []
for i in range(len(x)-1):
    arrow = go.Cone(
        x=[x[i+1]],
        y=[y[i+1]],
        z=[z[i+1]],
        u=[x[i+1]-x[i]],
        v=[y[i+1]-y[i]],
        w=[z[i+1]-z[i]],
        sizemode='absolute',
        sizeref=0.25,
        showscale=False,
        colorscale='Reds',
        opacity=0.5,
        name='Arrow '+str(i+1)
    )
    arrows.append(arrow)

# Create layout
layout = go.Layout(
    scene=dict(
        aspectmode="cube",
        xaxis=dict(title='X'),
        yaxis=dict(title='Y'),
        zaxis=dict(title='Z')
    )
)

# Create figure
fig = go.Figure(data=[trace_curve] + arrows, layout=layout)

# Show plot
fig.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a list of tuples containing (b, m, z)
data = maxm.tracking
# Find the tuple with the maximum z value
max_tuple = max(data, key=lambda x: x[2])
b_max, m_max, z_max = max_tuple

# Define the function b + m * log(x+1)
def function(x, b, m):
    return b + m * np.log(x + 1)

f = lambda x: function(x, b_max, m_max)

# Generate x values
x_values = np.linspace(0, 40, 1000)

# Generate y values using the function with the maximum b and m
y_values = function(x_values, b_max, m_max)

# Plot the function
plt.plot(x_values, y_values, label='b + m * log(x + 1)')

# Shade the area above the curve
plt.fill_between(x_values, y_values, max(y_values), color='green', alpha=0.3, where=(x_values >0)&(x_values<40))

# Shade the area below the curve
plt.fill_between(x_values, y_values, min(y_values), color='red', alpha=0.3, where=(x_values >0)&(x_values<40))

# Label the areas
plt.text(10, max(y_values) -0.5, 'ACEPTA', horizontalalignment='center', fontsize=12, color='green')
plt.text(20, min(y_values)+1, 'NO ACEPTA', horizontalalignment='center', fontsize=12, color='red')

# Add legend
plt.legend()

# Add labels and title
plt.xlabel('Horas Ocupadas')
plt.ylabel('Monto')
plt.title('Function b + m * log(x + 1)')

# Show plot
plt.grid(True)
plt.show()
