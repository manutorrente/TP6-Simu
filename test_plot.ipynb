# %%
import superficie_plot
import modelo
from importlib import reload
import variablesFijas
reload(superficie_plot)
reload(modelo)
# Out:
# <module 'modelo' from 'c:\\Users\\Manu\\OneDrive\\Escritorio\\UTN\\Simulación\\TP6\\modelo.py'>

# %%
n_repeticiones = 3
generadorSecuencias = variablesFijas.GeneradorDeSecuencias(n_repeticiones=n_repeticiones)

# %%
test_log = superficie_plot.SuperficiePlot(generadorSecuencias=generadorSecuencias, crit="log")
test_log.calcular_modelo(0,40,0,3,0.5,0.1)
test_log.plot()
test_log.plot_max()
# Out:
# Started process for 0.0 < x < 5.0
# Started process for 5.5 < x < 10.5
# Started process for 11.0 < x < 16.0
# Started process for 16.5 < x < 21.5
# Started process for 22.0 < x < 27.0
# Started process for 27.5 < x < 32.5
# Started process for 33.0 < x < 38.0
# Started process for 38.5 < x < 39.5
# Received 30 points. Total points: 30/2400
# Received 30 points. Total points: 60/2400
# Received 30 points. Total points: 90/2400
# Received 30 points. Total points: 120/2400
# Received 30 points. Total points: 150/2400
# Received 30 points. Total points: 180/2400
# Received 30 points. Total points: 210/2400
# Received 30 points. Total points: 240/2400
# Received 30 points. Total points: 270/2400
# Received 30 points. Total points: 300/2400
# Received 30 points. Total points: 330/2400
# Received 30 points. Total points: 360/2400
# Received 30 points. Total points: 390/2400
# Received 30 points. Total points: 420/2400
# Received 30 points. Total points: 450/2400
# Received 30 points. Total points: 480/2400
# Received 30 points. Total points: 510/2400
# Received 30 points. Total points: 540/2400
# Received 30 points. Total points: 570/2400
# Received 30 points. Total points: 600/2400
# Received 30 points. Total points: 630/2400
# Received 30 points. Total points: 660/2400
# Received 30 points. Total points: 690/2400
# Received 30 points. Total points: 720/2400
# Received 30 points. Total points: 750/2400
# Received 30 points. Total points: 780/2400
# Received 30 points. Total points: 810/2400
# Received 30 points. Total points: 840/2400
# Received 30 points. Total points: 870/2400
# Received 30 points. Total points: 900/2400
# Received 30 points. Total points: 930/2400
# Received 30 points. Total points: 960/2400
# Received 30 points. Total points: 990/2400
# Received 30 points. Total points: 1020/2400
# Received 30 points. Total points: 1050/2400
# Received 30 points. Total points: 1080/2400
# Received 30 points. Total points: 1110/2400
# Received 30 points. Total points: 1140/2400
# Received 30 points. Total points: 1170/2400
# Received 30 points. Total points: 1200/2400
# Received 30 points. Total points: 1230/2400
# Received 30 points. Total points: 1260/2400
# Received 30 points. Total points: 1290/2400
# Received 30 points. Total points: 1320/2400
# Received 30 points. Total points: 1350/2400
# Received 30 points. Total points: 1380/2400
# Received 30 points. Total points: 1410/2400
# Received 30 points. Total points: 1440/2400
# Received 30 points. Total points: 1470/2400
# Received 30 points. Total points: 1500/2400
# Received 30 points. Total points: 1530/2400
# Received 30 points. Total points: 1560/2400
# Received 30 points. Total points: 1590/2400
# Received 30 points. Total points: 1620/2400
# Received 30 points. Total points: 1650/2400
# Received 30 points. Total points: 1680/2400
# Received 30 points. Total points: 1710/2400
# Received 30 points. Total points: 1740/2400
# Received 30 points. Total points: 1770/2400
# Received 30 points. Total points: 1800/2400
# Received 30 points. Total points: 1830/2400
# Received 30 points. Total points: 1860/2400
# Received 30 points. Total points: 1890/2400
# Received 30 points. Total points: 1920/2400
# Received 30 points. Total points: 1950/2400
# Received 30 points. Total points: 1980/2400
# Received 30 points. Total points: 2010/2400
# Received 30 points. Total points: 2040/2400
# Received 30 points. Total points: 2070/2400
# Received 30 points. Total points: 2100/2400
# Received 30 points. Total points: 2130/2400
# Received 30 points. Total points: 2160/2400
# Received 30 points. Total points: 2190/2400
# Received 30 points. Total points: 2220/2400
# Received 30 points. Total points: 2250/2400
# Received 30 points. Total points: 2280/2400
# Received 30 points. Total points: 2310/2400
# Received 30 points. Total points: 2340/2400
# Received 30 points. Total points: 2370/2400
# Received 30 points. Total points: 2400/2400
# All processes finished

# %%
generadorSecuencias = variablesFijas.GeneradorDeSecuencias(n_repeticiones=3)
test_log = superficie_plot.SuperficiePlot(generadorSecuencias=generadorSecuencias, crit="lineal")
test_log.calcular_modelo(0,40,0,3,0.5,0.1)
test_log.plot()
test_log.plot_max()
# Out:
# Started process for 0.0 < x < 5.0
# Started process for 5.5 < x < 10.5
# Started process for 11.0 < x < 16.0
# Started process for 16.5 < x < 21.5
# Started process for 22.0 < x < 27.0
# Started process for 27.5 < x < 32.5
# Started process for 33.0 < x < 38.0
# Started process for 38.5 < x < 39.5
# Received 30 points. Total points: 30/2400
# Received 30 points. Total points: 60/2400
# Received 30 points. Total points: 90/2400
# Received 30 points. Total points: 120/2400
# Received 30 points. Total points: 150/2400
# Received 30 points. Total points: 180/2400
# Received 30 points. Total points: 210/2400
# Received 30 points. Total points: 240/2400
# Received 30 points. Total points: 270/2400
# Received 30 points. Total points: 300/2400
# Received 30 points. Total points: 330/2400
# Received 30 points. Total points: 360/2400
# Received 30 points. Total points: 390/2400
# Received 30 points. Total points: 420/2400
# Received 30 points. Total points: 450/2400
# Received 30 points. Total points: 480/2400
# Received 30 points. Total points: 510/2400
# Received 30 points. Total points: 540/2400
# Received 30 points. Total points: 570/2400
# Received 30 points. Total points: 600/2400
# Received 30 points. Total points: 630/2400
# Received 30 points. Total points: 660/2400
# Received 30 points. Total points: 690/2400
# Received 30 points. Total points: 720/2400
# Received 30 points. Total points: 750/2400
# Received 30 points. Total points: 780/2400
# Received 30 points. Total points: 810/2400
# Received 30 points. Total points: 840/2400
# Received 30 points. Total points: 870/2400
# Received 30 points. Total points: 900/2400
# Received 30 points. Total points: 930/2400
# Received 30 points. Total points: 960/2400
# Received 30 points. Total points: 990/2400
# Received 30 points. Total points: 1020/2400
# Received 30 points. Total points: 1050/2400
# Received 30 points. Total points: 1080/2400
# Received 30 points. Total points: 1110/2400
# Received 30 points. Total points: 1140/2400
# Received 30 points. Total points: 1170/2400
# Received 30 points. Total points: 1200/2400
# Received 30 points. Total points: 1230/2400
# Received 30 points. Total points: 1260/2400
# Received 30 points. Total points: 1290/2400
# Received 30 points. Total points: 1320/2400
# Received 30 points. Total points: 1350/2400
# Received 30 points. Total points: 1380/2400
# Received 30 points. Total points: 1410/2400
# Received 30 points. Total points: 1440/2400
# Received 30 points. Total points: 1470/2400
# Received 30 points. Total points: 1500/2400
# Received 30 points. Total points: 1530/2400
# Received 30 points. Total points: 1560/2400
# Received 30 points. Total points: 1590/2400
# Received 30 points. Total points: 1620/2400
# Received 30 points. Total points: 1650/2400
# Received 30 points. Total points: 1680/2400
# Received 30 points. Total points: 1710/2400
# Received 30 points. Total points: 1740/2400
# Received 30 points. Total points: 1770/2400
# Received 30 points. Total points: 1800/2400
# Received 30 points. Total points: 1830/2400
# Received 30 points. Total points: 1860/2400
# Received 30 points. Total points: 1890/2400
# Received 30 points. Total points: 1920/2400
# Received 30 points. Total points: 1950/2400
# Received 30 points. Total points: 1980/2400
# Received 30 points. Total points: 2010/2400
# Received 30 points. Total points: 2040/2400
# Received 30 points. Total points: 2070/2400
# Received 30 points. Total points: 2100/2400
# Received 30 points. Total points: 2130/2400
# Received 30 points. Total points: 2160/2400
# Received 30 points. Total points: 2190/2400
# Received 30 points. Total points: 2220/2400
# Received 30 points. Total points: 2250/2400
# Received 30 points. Total points: 2280/2400

# %%
resultados = []
limite = 18
secuencias = generadorSecuencias.nueva_secuencias()
for secuencia in secuencias:
    model = modelo.Modelo(limite, 0, aleatoriedad=secuencia, loops=10_000)
    resultados.append(model.simular()[0])
resultado = sum(resultados)/n_repeticiones
resultado
# Out:
# Ganancia semanal: 1013.8643594278557
# Promedio ocupación: 0.976482757723821
# Promedio rechazo cupo: 63.13999999999999
# Promedio rechazo monto: 20.39
# Ganancia semanal: 1038.8711165229665
# Promedio ocupación: 0.9722372341396428
# Promedio rechazo cupo: 64.31
# Promedio rechazo monto: 20.49
# Ganancia semanal: 1060.4371064384654
# Promedio ocupación: 0.9782820877427651
# Promedio rechazo cupo: 64.99000000000001
# Promedio rechazo monto: 19.919999999999998
# 1037.7241941297625

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function
f = lambda x: limite

# Generate x values
x_values = np.linspace(0, 40, 1000)

# Generate y values using the function with the maximum b and m
y_values = np.full_like(x_values, limite)  # Generate an array of the same length as x_values filled with limite

# Plot the function
plt.plot(x_values, y_values, label=f'y = {limite}')

# Shade the area below the curve in red
plt.fill_between(x_values, y_values, color='red', alpha=0.3)

# Shade the area above the curve in green
plt.fill_between(x_values, y_values, 40, color='green', alpha=0.3)

# Add legend
plt.legend()

# Add labels and title
plt.xlabel('Horas Ocupadas')
plt.ylabel('Monto')
plt.title('Criterio de aceptación')

plt.text(20, 35, 'ACEPTA', horizontalalignment='center', fontsize=12, color='green')
plt.text(20, 5, 'NO ACEPTA', horizontalalignment='center', fontsize=12, color='red')

plt.ylim(0, 40)
# Show plot
plt.grid(True)
plt.show()
