# %%
import superficie_plot
import modelo
from importlib import reload
reload(superficie_plot)
# Out:
# <module 'superficie_plot' from 'c:\\Users\\Manu\\OneDrive\\Escritorio\\UTN\\Simulación\\TP6\\superficie_plot.py'>

# %%
s = superficie_plot.SuperficiePlot(crit = "lineal", distribuciones=modelo.DistribucionesNuevas())
s.calcular_modelo(-40, 40, -3, 3, 0.5, 0.1)
# Out:
# Started process for -40.0 < x < -29.5
# Started process for -29.0 < x < -18.5
# Started process for -18.0 < x < -7.5
# Started process for -7.0 < x < 3.5
# Started process for 4.0 < x < 14.5
# Started process for 15.0 < x < 25.5
# Started process for 26.0 < x < 36.5
# Started process for 37.0 < x < 39.5
# Received 60 points. Total points: 60/9600
# Received 60 points. Total points: 120/9600
# Received 60 points. Total points: 180/9600
# Received 60 points. Total points: 240/9600
# Received 60 points. Total points: 300/9600
# Received 60 points. Total points: 360/9600
# Received 60 points. Total points: 420/9600
# Received 60 points. Total points: 480/9600
# Received 60 points. Total points: 540/9600
# Received 60 points. Total points: 600/9600
# Received 60 points. Total points: 660/9600
# Received 60 points. Total points: 720/9600
# Received 60 points. Total points: 780/9600
# Received 60 points. Total points: 840/9600
# Received 60 points. Total points: 900/9600
# ...

# %%
s.plot()
