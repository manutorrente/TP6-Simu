# %%
import pandas as pd
import numpy as np

df = pd.read_csv('consultasyhonorarios.csv')
df
# Out:
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
#          Fecha Honorarios  HonorariosCompletados
# 0   2024-02-11         31                     31
# 1   2024-02-14         40                     40
# 2   2024-02-17          -                     15
# 3   2024-02-22          -                     12
# 4   2024-02-24          -                     12
# 5   2024-02-28         24                     24
# 6   2024-03-02          -                     19
# 7   2024-03-07          -                     10
# 8   2024-03-11          -                     19
# 9   2024-03-13         22                     22
# 10  2024-03-18         21                     21
# 11  2024-03-20          -                      9
# 12  2024-03-23          -                     11
# 13  2024-03-28          -                     18
# 14  2024-03-31          -                     10
# 15  2024-04-04          -                     19
# 16  2024-04-06         22                     22
# 17  2024-04-08         25                     25
# 18  2024-04-12          -                      9
# 19  2024-04-16          -                     18
# 20  2024-04-20         22                     22
# 21  2024-04-22         30                     30
# 22  2024-04-24         35                     35
# 23  2024-04-28         25                     25
# 24  2024-04-30          -                     14

# %%
# si honorarios es "-" poner un numero random entre 8 y 20
df['HonorariosCompletados'] = df['Honorarios'].apply(lambda x: np.random.randint(8, 20) if x == '-' else x)
df.to_csv('consultasyhonorarios.csv', index=False)

# %%
diferencia_llegadas = []
fechas = df["Fecha"].to_list()
for i in range(len(fechas) - 1):
    fecha1 = pd.to_datetime(fechas[i])
    fecha2 = pd.to_datetime(fechas[i + 1])
    diferencia = fecha2 - fecha1
    diferencia_llegadas.append(diferencia)

#change timedelta to int in days
diferencia_llegadas = [x.days for x in diferencia_llegadas]
diferencia_llegadas
# Out:
# [0.42857142857142855,
#  0.42857142857142855,
#  0.7142857142857143,
#  0.2857142857142857,
#  0.5714285714285714,
#  0.42857142857142855,
#  0.7142857142857143,
#  0.5714285714285714,
#  0.2857142857142857,
#  0.7142857142857143,
#  0.2857142857142857,
#  0.42857142857142855,
#  0.7142857142857143,
#  0.42857142857142855,
#  0.5714285714285714,
#  0.2857142857142857,
#  0.2857142857142857,
#  0.5714285714285714,
#  0.5714285714285714,
#  0.5714285714285714,
#  0.2857142857142857,
#  0.2857142857142857,
#  0.5714285714285714,
#  0.2857142857142857]
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,

# %%
import pickle

from fitter import Fitter
fitter_llegadas = Fitter(diferencia_llegadas)
fitter_llegadas.fit()
fitter_llegadas.summary()
with open('fitter_llegadas.pkl', 'wb') as f:
    pickle.dump(fitter_llegadas, f)
# Out:
# 2024-05-05 16:56:51.949 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED _fit distribution (taking more than 30 seconds)
# 2024-05-05 16:56:52.250 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted anglit distribution with error=288.6886)
# 2024-05-05 16:56:52.915 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted argus distribution with error=288.784169)
# 2024-05-05 16:56:53.079 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted bradford distribution with error=284.658804)
# 2024-05-05 16:56:53.138 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted arcsine distribution with error=261.352433)
# 2024-05-05 16:56:53.227 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted alpha distribution with error=289.086224)
# 2024-05-05 16:56:53.277 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted betaprime distribution with error=288.741226)
# 2024-05-05 16:56:53.354 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=264.609543)
# 2024-05-05 16:56:53.551 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=290.458766)
# 2024-05-05 16:56:53.558 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr distribution with error=288.725751)
# 2024-05-05 16:56:53.726 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cosine distribution with error=288.884593)
# 2024-05-05 16:56:53.771 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr12 distribution with error=279.117666)
# 2024-05-05 16:56:53.799 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dgamma distribution with error=288.221036)
# 2024-05-05 16:56:53.843 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=283.835958)
# 2024-05-05 16:56:53.866 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dweibull distribution with error=288.314103)
# 2024-05-05 16:56:53.874 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi distribution with error=284.537997)
# 2024-05-05 16:56:54.303 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=245.67914)
# 2024-05-05 16:56:54.498 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fit
| INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wrapcauchy distribution with error=274.953388)
# 2024-05-05 16:57:14.590 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_max distribution with error=277.649525)
# 2024-05-05 16:57:22.931 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted recipinvgauss distribution with error=261.141223)
# 2024-05-05 16:57:26.170 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises_line distribution with error=285.979367)
# 2024-05-05 16:57:36.379 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED studentized_range distribution (taking more than 30 seconds)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,

# %%
fitter_honorarios = Fitter(df['HonorariosCompletados'].astype(int))
fitter_honorarios.fit()
fitter_honorarios.summary()
with open('fitter_honorarios.pkl', 'wb') as f:
    pickle.dump(fitter_honorarios, f)
# Out:
# 2024-05-05 18:39:25.480 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED _fit distribution (taking more than 30 seconds)
# 2024-05-05 18:39:26.568 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted alpha distribution with error=0.666654)
# 2024-05-05 18:39:27.440 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=0.642653)
# 2024-05-05 18:39:27.893 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted anglit distribution with error=0.675549)
# 2024-05-05 18:39:28.044 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted bradford distribution with error=0.66061)
# 2024-05-05 18:39:28.106 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted argus distribution with error=0.694377)
# 2024-05-05 18:39:28.175 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.672632)
# 2024-05-05 18:39:28.183 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr distribution with error=0.66615)
# 2024-05-05 18:39:28.375 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted arcsine distribution with error=0.676199)
# 2024-05-05 18:39:28.455 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cosine distribution with error=0.670662)
# 2024-05-05 18:39:28.846 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted betaprime distribution with error=0.645865)
# 2024-05-05 18:39:28.878 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dgamma distribution with error=0.669329)
# 2024-05-05 18:39:29.453 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted crystalball distribution with error=0.666442)
# 2024-05-05 18:39:29.621 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dweibull distribution with error=0.668368)
# 2024-05-05 18:39:30.302 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr12 distribution with error=0.66601)
# 2024-05-05 18:39:30.424 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponnorm distribution with error=0.668198)
# 2024-05-05 18:39:30.594 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi distribution with error=0.64968)
# 2024-05-05 18:39:30.645 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.643804)
# 2024-05-05 18:39:31.382 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted erlang distribution with error=0.654872)
# 2024-05-05 18:39:31.776 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.651247)
# 2024-05-05 18:39:32.154 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fatiguelife distribution with error=0.666761)
# 2024-05-05 18:39:32.763 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fisk distribution with error=0.669877)
# 2024-05-05 18:39:33.061 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponweib distribution with error=0.87617)
# 2024-05-05 18:39:33.857 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldnorm distribution with error=0.649244)
# 2024-05-05 18:39:34.046 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=0.652508)
# 2024-05-05 18:39:34.307 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted f distribution with error=0.645549)
# 2024-05-05 18:39:34.899 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldcauchy distribution with error=0.6591)
# 2024-05-05 18:39:34.899 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genextreme distribution with error=0.666652)
# 2024-05-05 18:39:35.406 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gausshyper distribution with error=0.638619)
# 2024-05-05 18:39:35.934 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gengamma distribution with error=0.827437)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:4937: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   return integrate.quad(llc, _a, x)[0]
# 2024-05-05 18:39:36.070 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhalflogistic distribution with error=0.650627)
# 2024-05-05 18:39:36.488 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.652642)
# 2024-05-05 18:39:36.522 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted geninvgauss distribution with error=0.643889)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3865: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   intgrl = integrate.quad(llc, x0, x1,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3865: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   intgrl = integrate.quad(llc, x0, x1,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3860: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   intgrl = (integrate.quad(llc, x0, mean,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3862: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   + integrate.quad(llc, mean, x1,
# 2024-05-05 18:39:36.623 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gennorm distribution with error=0.666602)
# 2024-05-05 18:39:37.585 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genlogistic distribution with error=0.666693)
# 2024-05-05 18:39:37.915 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genpareto distribution with error=0.685056)
# 2024-05-05 18:39:37.948 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genexpon distribution with error=0.690291)
# 2024-05-05 18:39:38.027 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhyperbolic distribution with error=0.646557)
# 2024-05-05 18:39:38.128 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_l distribution with error=0.679814)
# 2024-05-05 18:39:38.228 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfcauchy distribution with error=0.65843)
# 2024-05-05 18:39:38.273 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_r distribution with error=0.666663)
# 2024-05-05 18:39:38.424 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halflogistic distribution with error=0.651096)
# 2024-05-05 18:39:38.432 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfnorm distribution with error=0.649587)
# 2024-05-05 18:39:38.829 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted hypsecant distribution with error=0.666841)
# 2024-05-05 18:39:39.606 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gibrat distribution with error=0.666956)
# 2024-05-05 18:39:39.855 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgamma distribution with error=0.666981)
# 2024-05-05 18:39:39.898 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gompertz distribution with error=0.648404)
# 2024-05-05 18:39:40.222 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgauss distribution with error=0.666891)
# 2024-05-05 18:39:40.418 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invweibull distribution with error=0.666663)
# 2024-05-05 18:39:41.055 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted jf_skew_t distribution with error=0.667265)
# 2024-05-05 18:39:41.552 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsu distribution with error=0.667036)
# 2024-05-05 18:39:41.669 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kappa3 distribution with error=0.648707)
# 2024-05-05 18:39:41.867 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kstwo distribution (taking more than 30 seconds)
# 2024-05-05 18:39:42.196 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfgennorm distribution with error=0.663283)
# 2024-05-05 18:39:42.204 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ksone distribution with error=0.68135)
# 2024-05-05 18:39:42.897 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace distribution with error=0.664729)
# 2024-05-05 18:39:43.160 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace_asymmetric distribution with error=0.665736)
# 2024-05-05 18:39:43.370 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_l distribution with error=0.741181)
# 2024-05-05 18:39:43.963 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kstwobign distribution with error=0.665001)
# 2024-05-05 18:39:44.024 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted logistic distribution with error=0.66596)
# 2024-05-05 18:39:44.269 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loglaplace distribution with error=0.665986)
# 2024-05-05 18:39:44.444 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsb distribution with error=0.674058)
# 2024-05-05 18:39:44.566 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.684801)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# 2024-05-05 18:39:44.737 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loggamma distribution with error=0.666328)
# 2024-05-05 18:39:44.750 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy distribution with error=0.66895)
# 2024-05-05 18:39:45.341 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted maxwell distribution with error=0.664296)
# 2024-05-05 18:39:46.382 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted moyal distribution with error=0.668541)
# 2024-05-05 18:39:46.533 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED multivariate_normal distribution (taking more than 30 seconds)
# 2024-05-05 18:39:47.118 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loguniform distribution with error=0.644793)
# 2024-05-05 18:39:47.383 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_stable distribution with error=0.666005)
# 2024-05-05 18:39:47.875 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.666442)
# 2024-05-05 18:39:48.264 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lomax distribution with error=0.651365)
# 2024-05-05 18:39:48.640 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pareto distribution with error=0.690313)
# 2024-05-05 18:39:49.127 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ncx2 distribution with error=0.736965)
# 2024-05-05 18:39:49.523 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted mielke distribution with error=0.62716)
# 2024-05-05 18:39:49.624 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ncf distribution with error=0.666443)
# 2024-05-05 18:39:49.745 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nakagami distribution with error=0.629299)
# 2024-05-05 18:39:49.871 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nct distribution with error=0.666514)
# 2024-05-05 18:39:50.141 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norminvgauss distribution with error=0.666838)
# 2024-05-05 18:39:50.592 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.663352)
# 2024-05-05 18:39:51.134 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.693418)
# 2024-05-05 18:39:51.607 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rdist distribution with error=0.638245)
# 2024-05-05 18:39:53.386 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powernorm distribution with error=nan)
# 2024-05-05 18:39:53.464 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rel_breitwigner distribution with error=0.64901)
# 2024-05-05 18:39:53.910 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rice distribution with error=0.663352)
# 2024-05-05 18:39:54.108 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_continuous distribution (taking more than 30 seconds)
# 2024-05-05 18:39:54.220 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_histogram distribution (taking more than 30 seconds)
# 2024-05-05 18:39:54.878 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted reciprocal distribution with error=0.644793)
# 2024-05-05 18:39:55.213 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewcauchy distribution with error=0.672666)
# 2024-05-05 18:39:55.677 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pearson3 distribution with error=0.649381)
# 2024-05-05 18:39:57.335 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlognorm distribution with error=0.670052)
# 2024-05-05 18:39:57.905 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapezoid distribution with error=0.742995)
# 2024-05-05 18:39:57.906 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewnorm distribution with error=0.649585)
# 2024-05-05 18:39:57.907 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted t distribution with error=0.666442)
# 2024-05-05 18:39:57.988 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted semicircular distribution with error=0.675014)
# 2024-05-05 18:39:59.390 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapz distribution with error=0.742995)
# 2024-05-05 18:40:00.207 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncpareto distribution with error=0.646864)
# 2024-05-05 18:40:00.892 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncnorm distribution with error=0.733449)
# 2024-05-05 18:40:01.044 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncexpon distribution with error=0.652288)
# 2024-05-05 18:40:01.824 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises distribution with error=2.357558)
# 2024-05-05 18:40:01.965 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_fisher distribution (taking more than 30 seconds)
# 2024-05-05 18:40:02.091 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted tukeylambda distribution with error=0.656238)
# 2024-05-05 18:40:03.914 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wald distribution with error=0.668018)
# 2024-05-05 18:40:04.269 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.67846)
# 2024-05-05 18:40:05.426 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_max distribution with error=1.031619)
# 2024-05-05 18:40:05.814 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncweibull_min distribution with error=0.633132)
# 2024-05-05 18:40:08.003 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted triang distribution with error=0.648697)
# 2024-05-05 18:40:08.570 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_min distribution with error=0.64708)
# 2024-05-05 18:40:09.065 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wrapcauchy distribution with error=0.678461)
# 2024-05-05 18:40:11.087 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kappa4 distribution (taking more than 30 seconds)
# 2024-05-05 18:40:23.593 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted recipinvgauss distribution with error=0.666197)
# 2024-05-05 18:40:25.861 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED studentized_range distribution (taking more than 30 seconds)
# 2024-05-05 18:40:30.351 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises_line distribution with error=0.646795)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,

# %%
df_duracion = pd.read_csv('duracionterapia.csv')
fitter_duracion = Fitter(df_duracion['Duracion'])
fitter_duracion.fit()
fitter_duracion.summary()
with open('fitter_duracion.pkl', 'wb') as f:
    pickle.dump(fitter_duracion, f)
# Out:
# 2024-05-05 17:06:48.657 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED _fit distribution (taking more than 30 seconds)
# 2024-05-05 17:06:49.309 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted anglit distribution with error=0.13304)
# 2024-05-05 17:06:49.551 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted arcsine distribution with error=0.127678)
# 2024-05-05 17:06:50.106 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted beta distribution with error=0.120298)
# 2024-05-05 17:06:50.261 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cauchy distribution with error=0.133643)
# 2024-05-05 17:06:51.105 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted alpha distribution with error=0.129077)
# 2024-05-05 17:06:51.121 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted argus distribution with error=0.135402)
# 2024-05-05 17:06:51.754 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted cosine distribution with error=0.13317)
# 2024-05-05 17:06:51.857 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted bradford distribution with error=0.106769)
# 2024-05-05 17:06:51.903 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr12 distribution with error=0.12247)
# 2024-05-05 17:06:51.951 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi2 distribution with error=0.091226)
# 2024-05-05 17:06:52.054 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted betaprime distribution with error=0.108301)
# 2024-05-05 17:06:52.460 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted chi distribution with error=0.091208)
# 2024-05-05 17:06:52.908 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted burr distribution with error=0.124434)
# 2024-05-05 17:06:52.948 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dweibull distribution with error=0.130996)
# 2024-05-05 17:06:53.251 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted crystalball distribution with error=0.133285)
# 2024-05-05 17:06:53.345 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted expon distribution with error=0.124773)
# 2024-05-05 17:06:53.576 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted dgamma distribution with error=0.130346)
# 2024-05-05 17:06:54.226 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted erlang distribution with error=0.111887)
# 2024-05-05 17:06:55.191 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponnorm distribution with error=0.12476)
# 2024-05-05 17:06:55.936 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldcauchy distribution with error=0.126128)
# 2024-05-05 17:06:56.153 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponpow distribution with error=0.11093)
# 2024-05-05 17:06:56.307 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted f distribution with error=0.107441)
# 2024-05-05 17:06:56.864 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fatiguelife distribution with error=0.114146)
# 2024-05-05 17:06:57.398 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted fisk distribution with error=0.112802)
# 2024-05-05 17:06:57.863 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted foldnorm distribution with error=0.128689)
# 2024-05-05 17:06:58.361 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted exponweib distribution with error=0.093757)
# 2024-05-05 17:06:58.577 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gamma distribution with error=0.115943)
# 2024-05-05 17:06:58.830 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gausshyper distribution with error=0.125879)
# 2024-05-05 17:07:00.626 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genextreme distribution with error=0.086634)
# 2024-05-05 17:07:00.758 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genlogistic distribution with error=0.131874)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3865: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   intgrl = integrate.quad(llc, x0, x1,
# 2024-05-05 17:07:00.953 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gengamma distribution with error=0.097474)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3865: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   intgrl = integrate.quad(llc, x0, x1,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3860: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   intgrl = (integrate.quad(llc, x0, mean,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\stats\_continuous_distns.py:3862: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   + integrate.quad(llc, mean, x1,
# 2024-05-05 17:07:01.019 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genexpon distribution with error=0.124773)
# 2024-05-05 17:07:01.093 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhalflogistic distribution with error=0.13568)
# 2024-05-05 17:07:01.235 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genhyperbolic distribution with error=0.086282)
# 2024-05-05 17:07:01.660 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gibrat distribution with error=0.127985)
# 2024-05-05 17:07:02.459 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_l distribution with error=0.134542)
# 2024-05-05 17:07:02.968 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gumbel_r distribution with error=0.131882)
# 2024-05-05 17:07:02.984 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted geninvgauss distribution with error=0.108772)
# 2024-05-05 17:07:02.994 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfcauchy distribution with error=0.126146)
# 2024-05-05 17:07:03.168 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gennorm distribution with error=0.130443)
# 2024-05-05 17:07:03.791 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted genpareto distribution with error=0.128029)
# 2024-05-05 17:07:04.100 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halflogistic distribution with error=0.128085)
# 2024-05-05 17:07:04.407 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted hypsecant distribution with error=0.133364)
# 2024-05-05 17:07:05.089 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfnorm distribution with error=0.128517)
# 2024-05-05 17:07:05.527 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgamma distribution with error=0.130005)
# 2024-05-05 17:07:06.378 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted gompertz distribution with error=0.12618)
# 2024-05-05 17:07:06.506 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invweibull distribution with error=0.128113)
# 2024-05-05 17:07:06.615 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted invgauss distribution with error=0.126314)
# 2024-05-05 17:07:07.578 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsu distribution with error=0.101263)
# 2024-05-05 17:07:07.772 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted jf_skew_t distribution with error=0.130844)
# 2024-05-05 17:07:07.837 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED kstwo distribution (taking more than 30 seconds)
# 2024-05-05 17:07:08.285 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kappa3 distribution with error=0.130443)
# 2024-05-05 17:07:08.457 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace distribution with error=0.133385)
# 2024-05-05 17:07:08.825 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted laplace_asymmetric distribution with error=0.133806)
# 2024-05-05 17:07:08.830 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted halfgennorm distribution with error=0.100074)
# 2024-05-05 17:07:09.329 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ksone distribution with error=0.130837)
# 2024-05-05 17:07:10.160 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy distribution with error=0.110751)
# 2024-05-05 17:07:10.180 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kstwobign distribution with error=0.131652)
# 2024-05-05 17:07:10.226 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted johnsonsb distribution with error=0.093456)
# 2024-05-05 17:07:10.344 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_l distribution with error=0.138351)
# 2024-05-05 17:07:10.352 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted logistic distribution with error=0.133349)
# 2024-05-05 17:07:10.572 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loggamma distribution with error=0.133222)
# 2024-05-05 17:07:10.923 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loglaplace distribution with error=0.127241)
# 2024-05-05 17:07:12.112 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted maxwell distribution with error=0.132559)
# 2024-05-05 17:07:12.198 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lognorm distribution with error=0.115984)
# 2024-05-05 17:07:12.880 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted levy_stable distribution with error=0.13231)
# 2024-05-05 17:07:13.024 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted moyal distribution with error=0.131256)
# 2024-05-05 17:07:13.100 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED multivariate_normal distribution (taking more than 30 seconds)
# 2024-05-05 17:07:13.301 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted loguniform distribution with error=0.108875)
# 2024-05-05 17:07:13.501 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted lomax distribution with error=0.125348)
# 2024-05-05 17:07:13.605 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted mielke distribution with error=0.117591)
# 2024-05-05 17:07:13.928 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nakagami distribution with error=0.104615)
# 2024-05-05 17:07:15.355 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norm distribution with error=0.133285)
# 2024-05-05 17:07:16.416 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ncf distribution with error=0.095702)
# 2024-05-05 17:07:16.444 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlaw distribution with error=0.087849)
# 2024-05-05 17:07:16.532 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted ncx2 distribution with error=0.103028)
# 2024-05-05 17:07:16.838 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted nct distribution with error=0.110272)
# 2024-05-05 17:07:16.982 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted norminvgauss distribution with error=0.12634)
# 2024-05-05 17:07:17.020 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pareto distribution with error=0.089913)
# 2024-05-05 17:07:17.644 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rayleigh distribution with error=0.132223)
# 2024-05-05 17:07:18.511 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rdist distribution with error=0.128782)
# 2024-05-05 17:07:19.354 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rice distribution with error=0.132223)
# 2024-05-05 17:07:19.634 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_continuous distribution (taking more than 30 seconds)
# 2024-05-05 17:07:19.713 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powernorm distribution with error=nan)
# 2024-05-05 17:07:19.863 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED rv_histogram distribution (taking more than 30 seconds)
# 2024-05-05 17:07:20.041 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted reciprocal distribution with error=0.108875)
# 2024-05-05 17:07:20.628 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted rel_breitwigner distribution with error=0.129533)
# 2024-05-05 17:07:21.828 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewcauchy distribution with error=0.126146)
# 2024-05-05 17:07:22.190 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted pearson3 distribution with error=0.110167)
# 2024-05-05 17:07:22.298 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted semicircular distribution with error=0.132693)
# 2024-05-05 17:07:23.848 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapezoid distribution with error=0.138124)
# 2024-05-05 17:07:23.890 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted t distribution with error=0.133285)
# 2024-05-05 17:07:24.614 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted powerlognorm distribution with error=0.104058)
# 2024-05-05 17:07:24.866 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted skewnorm distribution with error=0.128517)
# 2024-05-05 17:07:25.122 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted trapz distribution with error=0.138124)
# 2024-05-05 17:07:27.313 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncexpon distribution with error=0.128134)
# 2024-05-05 17:07:27.850 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncpareto distribution with error=0.10871)
# 2024-05-05 17:07:28.538 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncnorm distribution with error=0.133285)
# 2024-05-05 17:07:29.028 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted vonmises distribution with error=2.516567)
# 2024-05-05 17:07:29.360 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted truncweibull_min distribution with error=0.12789)
# 2024-05-05 17:07:29.808 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_fisher distribution (taking more than 30 seconds)
# 2024-05-05 17:07:30.952 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted uniform distribution with error=0.130443)
# 2024-05-05 17:07:31.287 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wald distribution with error=0.128084)
# 2024-05-05 17:07:31.588 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted tukeylambda distribution with error=0.129026)
# 2024-05-05 17:07:32.741 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_max distribution with error=0.156404)
# 2024-05-05 17:07:33.701 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted triang distribution with error=0.127682)
# 2024-05-05 17:07:33.908 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted wrapcauchy distribution with error=0.126639)
# 2024-05-05 17:07:33.931 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted kappa4 distribution with error=0.127538)
# 2024-05-05 17:07:34.240 | INFO     | fitter.fitter:_fit_single_distribution:337 - Fitted weibull_min distribution with error=0.112147)
# 2024-05-05 17:07:48.193 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED recipinvgauss distribution (taking more than 30 seconds)
# 2024-05-05 17:07:51.447 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED studentized_range distribution (taking more than 30 seconds)
# 2024-05-05 17:08:00.281 | WARNING  | fitter.fitter:_fit_single_distribution:347 - SKIPPED vonmises_line distribution (taking more than 30 seconds)
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# c:\Users\Manu\OneDrive\Escritorio\UTN\Simulación\TP6\TP6Venv\Lib\site-packages\scipy\integrate\_quadpack_py.py:1272: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,

# %%
best_llegadas = fitter_llegadas.get_best()["exponpow"]
best_honorarios = fitter_honorarios.get_best()["mielke"]
best_duracion = fitter_duracion.get_best()["genhyperbolic"]
print(best_llegadas)
print(best_honorarios)
print(best_duracion)
# Out:
# {'b': 0.2530355326169663, 'loc': 1.9999999999999998, 'scale': 2.220442218350816}
# {'k': 0.6537121713667068, 's': 4.535972358049413, 'loc': 8.999999793193584, 'scale': 21.772360198928865}
# {'p': 0.24829868410300127, 'a': 0.9027799441751452, 'b': 0.9027799436159013, 'loc': 1.9999999434593596, 'scale': 7.062554221953598e-08}

# %%
from scipy.stats import exponpow, mielke, genhyperbolic

distribucion_llegada = lambda : exponpow.rvs(best_llegadas[0]["b"], loc=best_llegadas[0]["loc"], scale=best_llegadas[0]["scale"])

distribucion_honorarios = lambda : mielke.rvs(best_honorarios[0]["k"], best_honorarios[0]["s"], loc=best_honorarios[0]["loc"], scale=best_honorarios[0]["scale"])

distribucion_duracion = lambda : genhyperbolic.rvs(best_duracion[0]["p"], best_duracion[0]["a"], best_duracion[0]["b"], loc=best_duracion[0]["loc"], scale=best_duracion[0]["scale"])

# %%
#plot llegadas
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import exponpow  # Example distribution, replace with your distribution

# Assuming you have the parameters for your distribution
# Replace 'dist' with your specific distribution and pass the parameters accordingly
params = (best_llegadas["b"],)  # Example parameters for mean=0 and standard deviation=1

# Additional keyword arguments
kwargs = {'loc': best_llegadas["loc"], 'scale': best_llegadas["scale"]}  # Example for loc and scale, replace with your specific kwargs

# Generate data points
x = np.linspace(1, 5, 1000)

# Calculate the density function using the pdf method of the distribution
density = exponpow.pdf(x, *params, **kwargs)  # Replace 'norm' with your specific distribution

# Plot the density function
plt.plot(x, density)
plt.xlabel('x')
plt.ylabel('Density')
plt.title('Density Function')
plt.grid(True)
plt.show()

# %%
#plot honorarios
from scipy.stats import mielke  # Example distribution, replace with your distribution

# Assuming you have the parameters for your distribution
# Replace 'dist' with your specific distribution and pass the parameters accordingly
params = (best_honorarios["k"], best_honorarios["s"])  # Example parameters for mean=0 and standard deviation=1

# Additional keyword arguments
kwargs = {'loc': best_honorarios["loc"], 'scale': best_honorarios["scale"]}  # Example for loc and scale, replace with your specific kwargs

# Generate data points
x = np.linspace(0, 40, 1000)

# Calculate the density function using the pdf method of the distribution
density = mielke.pdf(x, *params, **kwargs)  # Replace 'norm' with your specific distribution

# Plot the density function
plt.plot(x, density)
plt.xlabel('x')
plt.ylabel('Density')
plt.title('Density Function')
plt.grid(True)
plt.show()
